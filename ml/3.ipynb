# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
df = pd.read_csv(r"C:\Users\aishu\Desktop\DB Tracks - Sheet1.csv", encoding="ISO-8859-1")
df
# Out:
#                         Song name  \
# 0                         Cloud 9
# 1                    un-unnoticed
# 2                              22
# 3                abcdfu (angrier)
# 4               Happier Than Ever
# ..                            ...
# 95                        Bound 2
# 96  Father Stretch My Hands Pt. 1
# 97                       Stronger
# 98                          POWER
# 99                      Heartless
#
#                                                 Genre         Artist  \
# 0                                           indie pop    Beach Bunny
# 1                                           indie pop           Zeph
# 2                                                 pop   Taylor Swift
# 3                                  pop rock, pop punk          GAYLE
# 4                                      rock, pop punk  Billie Eilish
# ..                                                ...            ...
# 95                                       hip-hop, rap             Ye
# 96                                       hip-hop, rap             Ye
# 97                                       hip-hop, rap             Ye
# 98                                       hip-hop, rap             Ye
# 99  hip-hop, rap, rhythm and blues, electronic dan...             Ye
#
#                            Album Name  Play count  Unnamed: 5    Artist name  \
# 0                           Honeymoon   231581302         NaN    Beach Bunny
# 1                scared of everything     5580675         NaN           Zeph
# 2                                 Red   315678924         NaN  Taylor Swift
# 3                     abcdfu - single   680563426         NaN         GAYLE
# 4                   Happier Than Ever   641415612         NaN  Billie Eilish
# ..                                ...         ...         ...            ...
# 95                             Yeezus   376442702         NaN            NaN
# 96                  The Life of Pablo   509699887         NaN            NaN
# 97                         Graduation  1008657841         NaN            NaN
# 98  My Beautiful Dark Twisted Fantasy   295313959         NaN            NaN
# 99                  808s & Heartbreak   535632658         NaN            NaN
#
#                                                  Link               Album 1  \
# 0   https://instagram.com/beachbunnymusic?igshid=Y...             Honeymoon
# 1   https://instagram.com/zephanijong?igshid=YmMyM...  scared of everything
# 2   https://instagram.com/taylorswift?igshid=YmMyM...                   Red
# 3     https://instagram.com/gayle?igshid=YmMyMTA2M2Y=       abcdfu - single
# 4   https://instagram.com/billieeilish?igshid=YmMy...     Happier Than Ever
# ..                                                ...                   ...
# 95                                                NaN                   NaN
# 96                                                NaN                   NaN
# 97                                                NaN                   NaN
# 98                                                NaN                   NaN
# 99                                                NaN                   NaN
#
#               Album 2   Album 3 Album 4 Album 5
# 0                 NaN       NaN     NaN     NaN
# 1                 NaN       NaN     NaN     NaN
# 2            evermore  folklore     NaN     NaN
# 3                 NaN       NaN     NaN     NaN
# 4   come out and play       NaN     NaN     NaN
# ..                ...       ...     ...     ...
# 95                NaN       NaN     NaN     NaN
# 96                NaN       NaN     NaN     NaN
# 97                NaN       NaN     NaN     NaN
# 98                NaN       NaN     NaN     NaN
# 99                NaN       NaN     NaN     NaN
#
# [100 rows x 13 columns]

# %%
arr = []
for i in range(len(df['Album Name'])):
    arr.append( [df['Song name'][i], df['Album Name'][i], df['Genre'][i], df['Play count'][i] ])

for j, i in enumerate(arr):
    print(j + 1, i[0], i[1], i[2], i[3])

    genres = i[2].split(', ')
    print(genres)
    for genre in genres:
        genre = str(genre).strip()
        print(genre)
# Out:
# 1 Cloud 9 Honeymoon indie pop 231581302
# ['indie pop']
# indie pop
# 2 un-unnoticed scared of everything indie pop 5580675
# ['indie pop']
# indie pop
# 3 22 Red pop 315678924
# ['pop']
# pop
# 4 abcdfu (angrier) abcdfu - single pop rock, pop punk 680563426
# ['pop rock', 'pop punk']
# pop rock
# pop punk
# 5 Happier Than Ever Happier Than Ever rock, pop punk 641415612
# ['rock', 'pop punk']
# rock
# pop punk
# 6 Adios Departure r&b, pop, hip-hop 27529846
# ['r&b', 'pop', 'hip-hop']
# r&b
# pop
# hip-hop
# 7 evermore evermore alternative, indie, pop 150783426
# ['alternative', 'indie', 'pop']
# alternative
# indie
# pop
# 8 happiness evermore alternative, indie, pop 75899437
# ['alternative', 'indie', 'pop']
# alternative
# indie
# pop
# 9 the 1 folklore alternative, indie 115768453
# ['alternative', 'indie']
# alternative
# indie
# 10 Blue froot alternative, pop, indie 286395104
# ['alternative', 'pop', 'indie']
# alternative
# pop
# indie
# 11 Stay Fck Love pop rock, synth pop 1838478793
# ['pop rock', 'synth pop']
# pop rock
# synth pop
# 12 Woman Planer Her r&b, soul 853547845
# ['r&b', 'soul']
# r&b
# soul
# 13 good 4 u Sour pop punk, pop rock 1461994908
# ['pop punk', 'pop rock']
# pop punk
# pop rock
# 14 Sweater Weather I Love You indie rock, alternative, indie, pop 1487453136
# ['indie rock', 'alternative', 'indie', 'pop']
# indie rock
# alternative
# indie
# pop
# 15 As It Was Harry's House new wave, synth pop 610082027
# ['new wave', 'synth pop']
# new wave
# synth pop
# 16 Found My Friends PANORAMA r&b, soul, pop 13258080
# ['r&b', 'soul', 'pop']
# r&b
# soul
# pop
# 17 SHIWAKUCHA FOREVER DAZE indie, japanese rock 66245539
# ['indie', 'japanese rock']
# indie
# japanese rock
# 18 Moral of the Story To All the Boys: P.S. I Still Love You indie, pop 401412757
# ['indie', 'pop']
# indie
# pop
# 19 Light Switch Light Switch - single pop 222807157
# ['pop']
# pop
# 20 How You Like That The Album k-pop, pop, hip-hop 629798244
# ['k-pop', 'pop', 'hip-hop']
# k-pop
# pop
# hip-hop
# 21 Pretty Savage The Album k-pop, electronic, trap 241787205
# ['k-pop', 'electronic', 'trap']
# k-pop
# electronic
# trap
# 22 Change 4 Your Eyez Only r&b, hip-hop 378677342
# ['r&b', 'hip-hop']
# r&b
# hip-hop
# 23 Neighbors 4 Your Eyez Only hip-hop, jazz rap 299677342
# ['hip-hop', 'jazz rap']
# hip-hop
# jazz rap
# 24 No Role Modelz 2014 Forest Hills Drive r&b, hip-hop 1277075750
# ['r&b', 'hip-hop']
# r&b
# hip-hop
# 25 She Knows Born Sinner r&b, hip-hop 362536937
# ['r&b', 'hip-hop']
# r&b
# hip-hop
# 26 No Better Pure Heroine alternative, indie, pop 87653479
# ['alternative', 'indie', 'pop']
# alternative
# indie
# pop
# 27 Rolling in the Deep 21 r&b, soul, pop 1122790452
# ['r&b', 'soul', 'pop']
# r&b
# soul
# pop
# 28 Hello 25 r&b, soul, pop, uk r&b 1356789268
# ['r&b', 'soul', 'pop', 'uk r&b']
# r&b
# soul
# pop
# uk r&b
# 29 Sunflower Spider-Man Into the Spider-Verse hip-hop, rhythm and blues, dream pop, r&b, soul 2304175255
# ['hip-hop', 'rhythm and blues', 'dream pop', 'r&b', 'soul']
# hip-hop
# rhythm and blues
# dream pop
# r&b
# soul
# 30 Waste It On Me Neon Future III rop, latin urbano, dance, electronic 238201756
# ['rop', 'latin urbano', 'dance', 'electronic']
# rop
# latin urbano
# dance
# electronic
# 31 come out and play come out and play alternative, indie pop 780894019
# ['alternative', 'indie pop']
# alternative
# indie pop
# 32 Malibu Nights Malibu Nights alternative, indie pop 277444172
# ['alternative', 'indie pop']
# alternative
# indie pop
# 33 Thick And Thin Malibu Nights alternative, indie pop  113007923
# ['alternative', 'indie pop ']
# alternative
# indie pop
# 34 Super Far LANY alternative, indie pop  100892473
# ['alternative', 'indie pop ']
# alternative
# indie pop
# 35 ILYSB LANY alternative, indie pop, r&b, soul 162060911
# ['alternative', 'indie pop', 'r&b', 'soul']
# alternative
# indie pop
# r&b
# soul
# 36 Love It If We Made It A Brief Inquiry into Online Relationships alternative, indie pop, r&b, soul 168442333
# ['alternative', 'indie pop', 'r&b', 'soul']
# alternative
# indie pop
# r&b
# soul
# 37 The Sound I Like It When You Sleep, for You Are So Beautiful Yet So Unaware of It alternative, indie 174894567
# ['alternative', 'indie']
# alternative
# indie
# 38 Blinding Lights Blinding Lights r&b, soul, synthwave 2978276702
# ['r&b', 'soul', 'synthwave']
# r&b
# soul
# synthwave
# 39 In Your Eyes After Hours r&b, soul 304563988
# ['r&b', 'soul']
# r&b
# soul
# 40 Circles Hollywood's Bleeding pop rock, soft rock, downtempo, hip-hop, rap 1743913133
# ['pop rock', 'soft rock', 'downtempo', 'hip-hop', 'rap']
# pop rock
# soft rock
# downtempo
# hip-hop
# rap
# 41 Somebody Else I Like It When You Sleep, for You Are So Beautiful Yet So Unaware of It synth-pop, alternative, indie 563904380
# ['synth-pop', 'alternative', 'indie']
# synth-pop
# alternative
# indie
# 42 LOSER/LOVER The Chaos Chapter FIGHT OR ESCAPE r&b, soul, dance,elecronic, k-pop, pop, hip-hop 109191647
# ['r&b', 'soul', 'dance,elecronic', 'k-pop', 'pop', 'hip-hop']
# r&b
# soul
# dance,elecronic
# k-pop
# pop
# hip-hop
# 43 Magic The Chaos Chapter FREEZE electronic, korea dance, k-pop 117684807
# ['electronic', 'korea dance', 'k-pop']
# electronic
# korea dance
# k-pop
# 44 0X1/LOVESONG The Chaos Chapter FREEZE rock, korea dance, electronic, k-pop 134150831
# ['rock', 'korea dance', 'electronic', 'k-pop']
# rock
# korea dance
# electronic
# k-pop
# 45 Oinamaqo Live Performance 2020, Pt. 1 q-pop, alternative, indie, japanese hip hop, hip-hop, indonisian indie, j-pop 447582
# ['q-pop', 'alternative', 'indie', 'japanese hip hop', 'hip-hop', 'indonisian indie', 'j-pop']
# q-pop
# alternative
# indie
# japanese hip hop
# hip-hop
# indonisian indie
# j-pop
# 46 SeÃ±orita 91 pop, q-pop 433846
# ['pop', 'q-pop']
# pop
# q-pop
# 47 Alystama Alystama rock 313292
# ['rock']
# rock
# 48 Ozin Gana Ozin Gana pop 214327
# ['pop']
# pop
# 49 The Feels The Feels k-pop, dance, electronic, korea dance 211036166
# ['k-pop', 'dance', 'electronic', 'korea dance']
# k-pop
# dance
# electronic
# korea dance
# 50 I Can't Stop Me Eyes wide open r&b, soul, k-pop, korea dance, electronic 241193376
# ['r&b', 'soul', 'k-pop', 'korea dance', 'electronic']
# r&b
# soul
# k-pop
# korea dance
# electronic
# 51 FANCY Fancy You k-pop, korea dance, electronic 313657458
# ['k-pop', 'korea dance', 'electronic']
# k-pop
# korea dance
# electronic
# 52 YES or YES Yes or Yes k-pop, korea dance, electronic 176510518
# ['k-pop', 'korea dance', 'electronic']
# k-pop
# korea dance
# electronic
# 53 Feel My Rythm The ReVe Festival 2022 k-pop, korea dance, electronic 45878636
# ['k-pop', 'korea dance', 'electronic']
# k-pop
# korea dance
# electronic
# 54 Peek-A-Boo Perfect Velvet k-pop, korea dance, electronic 152257856
# ['k-pop', 'korea dance', 'electronic']
# k-pop
# korea dance
# electronic
# 55 Roses Bouquet trap music, dance, electronic, future bass, pop 889256643
# ['trap music', 'dance', 'electronic', 'future bass', 'pop']
# trap music
# dance
# electronic
# future bass
# pop
# 56 Paris Memories...Do Not Open pop, electronic dance, synth-pop, pop  974808224
# ['pop', 'electronic dance', 'synth-pop', 'pop ']
# pop
# electronic dance
# synth-pop
# pop
# 57 Closer Collage electronic dance, pop, dance 2290700698
# ['electronic dance', 'pop', 'dance']
# electronic dance
# pop
# dance
# 58 Something Just Like This  Memories...Do Not Open electronic dance, pop, dance 1826114133
# ['electronic dance', 'pop', 'dance']
# electronic dance
# pop
# dance
# 59 One Kiss Dua Lipa dance pop, diva house, reggae, r&b, soul, dance, electronic, tropical house, pop 1378051237
# ['dance pop', 'diva house', 'reggae', 'r&b', 'soul', 'dance', 'electronic', 'tropical house', 'pop']
# dance pop
# diva house
# reggae
# r&b
# soul
# dance
# electronic
# tropical house
# pop
# 60 This Is What You Came For This Is What You Came For electronic dance, pop, dance 602153673
# ['electronic dance', 'pop', 'dance']
# electronic dance
# pop
# dance
# 61 How Deep Is Your Love How Deep Is Your Love electronic dance, dance, pop 874890955
# ['electronic dance', 'dance', 'pop']
# electronic dance
# dance
# pop
# 62 iâm so tiredâ¦ I Met You When I Was 18 alternative, indie, pop, dance, electronic 740659792
# ['alternative', 'indie', 'pop', 'dance', 'electronic']
# alternative
# indie
# pop
# dance
# electronic
# 63 Maps V pop rock, pop 979489587
# ['pop rock', 'pop']
# pop rock
# pop
# 64 Sugar V alternative, indie, pop, dance, electronic 1365837103
# ['alternative', 'indie', 'pop', 'dance', 'electronic']
# alternative
# indie
# pop
# dance
# electronic
# 65 Animals V pop rock, pop 907391915
# ['pop rock', 'pop']
# pop rock
# pop
# 66 Love Again Future Nostalgia (The Moonlight Edition) pop 908591947
# ['pop']
# pop
# 67 Don't Start Now Don't Start Now pop 1909969680
# ['pop']
# pop
# 68 Levitating Future Nostalgia  electro, space rock, nu-disco, pop funk, pop 518645643
# ['electro', 'space rock', 'nu-disco', 'pop funk', 'pop']
# electro
# space rock
# nu-disco
# pop funk
# pop
# 69 New Rules Dua Lipa r&b, soul, pop, dance, electronic, reggae 1686303312
# ['r&b', 'soul', 'pop', 'dance', 'electronic', 'reggae']
# r&b
# soul
# pop
# dance
# electronic
# reggae
# 70 Physical Future Nostalgia (The Moonlight Edition) r&b, soul, latin urbano 513982977
# ['r&b', 'soul', 'latin urbano']
# r&b
# soul
# latin urbano
# 71 Say So Hot Pink pop, r&b, soul, disco, pop rap 964061139
# ['pop', 'r&b', 'soul', 'disco', 'pop rap']
# pop
# r&b
# soul
# disco
# pop rap
# 72 Shut Up and Drive Good Girl Gone Bad r&b, soul, pop, uk r&b 576764588
# ['r&b', 'soul', 'pop', 'uk r&b']
# r&b
# soul
# pop
# uk r&b
# 73 Umbrella Good Girl Gone Bad r&b, soul, pop, uk r&b 883028763
# ['r&b', 'soul', 'pop', 'uk r&b']
# r&b
# soul
# pop
# uk r&b
# 74 Photograph Ã folk music, dance, electronic, hip-hop, pop, french urban pop, r&b, soul 1876750761
# ['folk music', 'dance', 'electronic', 'hip-hop', 'pop', 'french urban pop', 'r&b', 'soul']
# folk music
# dance
# electronic
# hip-hop
# pop
# french urban pop
# r&b
# soul
# 75 Perfect Divide pop 2070695444
# ['pop']
# pop
# 76 Shivers Equals alternative, indie, dance, electronic, r&b, soul, pop 787347866
# ['alternative', 'indie', 'dance', 'electronic', 'r&b', 'soul', 'pop']
# alternative
# indie
# dance
# electronic
# r&b
# soul
# pop
# 77 Treat You Better Illuminate pop 1538903151
# ['pop']
# pop
# 78 There's Nothing Holdin' Me Back Illuminate pop 1343398827
# ['pop']
# pop
# 79 Stitches Handwritten pop, r&b soul 1393339319
# ['pop', 'r&b soul']
# pop
# r&b soul
# 80 Itâll Be Okay Itâll Be Okay classic soul, singer-songwriter 161551470
# ['classic soul', 'singer-songwriter']
# classic soul
# singer-songwriter
# 81 Rain On Me Chromatica disco, electropop, pop, house music, dance, electronic 778043161
# ['disco', 'electropop', 'pop', 'house music', 'dance', 'electronic']
# disco
# electropop
# pop
# house music
# dance
# electronic
# 82 One Last Time My Everything pop, r&b, soul, german pop 956289665
# ['pop', 'r&b', 'soul', 'german pop']
# pop
# r&b
# soul
# german pop
# 83 No Tears Left to Cry Sweetener dance pop, disco, dance-r&b 540085331
# ['dance pop', 'disco', 'dance-r&b']
# dance pop
# disco
# dance-r&b
# 84 Into You Dangerous Woman pop, r&b, soul 698215907
# ['pop', 'r&b', 'soul']
# pop
# r&b
# soul
# 85 7 Rings thank u, next hip-hop, pop, trap music, rhytm and blues 1734172999
# ['hip-hop', 'pop', 'trap music', 'rhytm and blues']
# hip-hop
# pop
# trap music
# rhytm and blues
# 86 O_o Qarangy Zharyq indian pop, indian pop 405339
# ['indian pop', 'indian pop']
# indian pop
# indian pop
# 87 5000 13 Vypusk hip-hop, rap, thai hip hop 6411780
# ['hip-hop', 'rap', 'thai hip hop']
# hip-hop
# rap
# thai hip hop
# 88 Arriva 13 Vypusk rap, hip-hop 1696798
# ['rap', 'hip-hop']
# rap
# hip-hop
# 89 NE ÃÅGIME? NE ANGIME? rap, hip-hop 3284159
# ['rap', 'hip-hop']
# rap
# hip-hop
# 90 Kettik Kettik rap, hip-hop 875073
# ['rap', 'hip-hop']
# rap
# hip-hop
# 91 Do I Wanna Know? AM post-britpop, psychedelic rock 1336892790
# ['post-britpop', 'psychedelic rock']
# post-britpop
# psychedelic rock
# 92 Fluorescent Adolescent Favourite Worst Nightmare alternative, indie 530399608
# ['alternative', 'indie']
# alternative
# indie
# 93 I Wanna Be Yours AM alternative, indie 468738950
# ['alternative', 'indie']
# alternative
# indie
# 94 Whyâd You Only Call Me When Youâre High? AM alternative, indie 839729796
# ['alternative', 'indie']
# alternative
# indie
# 95 505 Favourite Worst Nightmare alternative, indie 633982205
# ['alternative', 'indie']
# alternative
# indie
# 96 Bound 2 Yeezus hip-hop, rap 376442702
# ['hip-hop', 'rap']
# hip-hop
# rap
# 97 Father Stretch My Hands Pt. 1 The Life of Pablo hip-hop, rap 509699887
# ['hip-hop', 'rap']
# hip-hop
# rap
# 98 Stronger Graduation hip-hop, rap 1008657841
# ['hip-hop', 'rap']
# hip-hop
# rap
# 99 POWER My Beautiful Dark Twisted Fantasy hip-hop, rap 295313959
# ['hip-hop', 'rap']
# hip-hop
# rap
# 100 Heartless 808s & Heartbreak hip-hop, rap, rhythm and blues, electronic dance, hip-hop, rap, r&b, soul 535632658
# ['hip-hop', 'rap', 'rhythm and blues', 'electronic dance', 'hip-hop', 'rap', 'r&b', 'soul']
# hip-hop
# rap
# rhythm and blues
# electronic dance
# hip-hop
# rap
# r&b
# soul
